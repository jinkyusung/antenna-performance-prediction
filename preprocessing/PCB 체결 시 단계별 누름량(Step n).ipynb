# %% [markdown]
# # PCB 체결 시 단계별 누름량(Step n)
# `X_01`  `X_02`  `X_05`  `X_06`

# %%
import pandas as pd
import sys, os


sys.path.append('..')

# %%
from mylibrary import visualization as visual


x_feat = pd.read_csv('../dataset/x_feature/PCB 체결 시 단계별 누름량(Step n).csv')
print(feature.describe())
visual.show_plot(feature)
# Out:
#                X_01          X_02          X_05          X_06
# count  39607.000000  39607.000000  39607.000000  39607.000000
# mean      68.412040    103.320166    102.337203     70.597211
# std        2.655983      0.000372      0.548353      2.259820
# min       56.268000    103.320000    101.774000     61.726000
# 25%       66.465000    103.320000    101.949000     68.864000
# 50%       68.504000    103.320000    102.006000     69.884000
# 75%       69.524000    103.320000    103.144000     71.923000
# max       84.820000    103.321000    103.160000     87.219000

# %%
visual.corr_heatmap(x_feat)
visual.corr_heatmap_with_y(x_feat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 visual.corr_heatmap(x_feat)
# ----> 2 visual.corr_heatmap_with_y(x_feat)
#
# File C:\Github\antenna-performance-prediction\preprocessing\..\mylibrary\visualization.py:72, in corr_heatmap_with_y(x_df)
#      69 correlation = tmp.corr().filter(regex='Y').filter(regex='X', axis=0)
#      71 n = len(correlation.index)
# ---> 72 m = len(correlation.column)
#      74 plt.figure(figsize=(m, n))
#      75 sns.heatmap(correlation, annot=True)
#
# File C:\Anaconda\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
# ...

# %% [markdown]
# # PCB 체결 시 단계별 누름량(Step n)
# `X_01`  `X_02`  `X_05`  `X_06`

# %%
import pandas as pd
import sys


sys.path.append('..')

# %%
from mylibrary import visualization as visual


feat = pd.read_csv('../dataset/x_feature/PCB 체결 시 단계별 누름량(Step n).csv')
print(feat.describe())
visual.show_plot(feat)
# Out:
#                X_01          X_02          X_05          X_06
# count  39607.000000  39607.000000  39607.000000  39607.000000
# mean      68.412040    103.320166    102.337203     70.597211
# std        2.655983      0.000372      0.548353      2.259820
# min       56.268000    103.320000    101.774000     61.726000
# 25%       66.465000    103.320000    101.949000     68.864000
# 50%       68.504000    103.320000    102.006000     69.884000
# 75%       69.524000    103.320000    103.144000     71.923000
# max       84.820000    103.321000    103.160000     87.219000

# %%
visual.corr_heatmap(feat)
visual.corr_heatmap_with_y(feat)

# %%
y1 = pd.read_csv('../dataset/y_feature/신호대 잡음비 (각도n).csv')
y2 = pd.read_csv('../dataset/y_feature/안테나 Gain 평균 (각도n).csv')
y3 = pd.read_csv('../dataset/y_feature/안테나 n Gain 편차.csv')
y4 = pd.read_csv('../dataset/y_feature/평균 신호대 잡음비.csv')
y_feat = [y1, y2, y3, y4]

for x in feat:
    for y in y_feat:
        visual.x_to_y_visualize(feat[x], y)
